# %% [markdown]
# must run
#
# mac:
# brew install ffmpeg
#
# linux:
# sudo apt install ffmpeg
#
# windows:
# Download from https://ffmpeg.org and add to PATH.

# %%
import os
import subprocess
from pathlib import Path

# ====== CONFIGURATION ======

INPUT_ROOT = Path("./data")
OUTPUT_ROOT = Path("./data_processed")

# Target settings
TARGET_WIDTH = 640     # downscale width
TARGET_HEIGHT = 480    # downscale height
TARGET_FPS = 15        # reduce framerate

CRF_QUALITY = 23       # 18=high quality, 23=default, 28=smaller file

print("Input directory:", INPUT_ROOT.resolve())
print("Output directory:", OUTPUT_ROOT.resolve())
# Out:
# Input directory: C:\Projects\gaitkeeper\data
# Output directory: C:\Projects\gaitkeeper\data_processed

# %%
def process_video(input_path, output_path):
    output_path.parent.mkdir(parents=True, exist_ok=True)

    command = [
        "ffmpeg",
        "-y",  # overwrite existing files
        "-i", str(input_path),
        "-vf", f"scale={TARGET_WIDTH}:{TARGET_HEIGHT},fps={TARGET_FPS}",
        "-c:v", "libx264",
        "-preset", "medium",
        "-crf", str(CRF_QUALITY),
        "-pix_fmt", "yuv420p",
        "-an",  # remove audio (usually unnecessary for ML)
        str(output_path)
    ]

    print(f"Processing: {input_path.name}")
    subprocess.run(command)
    print(f"Saved → {output_path}")

# %%
def batch_process_videos():
    for category_dir in INPUT_ROOT.iterdir():
        if category_dir.is_dir():
            category_name = category_dir.name
            for video_file in category_dir.glob("*.mov"):
                output_dir = OUTPUT_ROOT / category_name
                output_file = output_dir / (video_file.stem + ".mp4")

                process_video(video_file, output_file)


    print("\n All videos processed.")

batch_process_videos()
# Out:
# Processing: j_complex1.mov
# Saved → data_processed\jacket\j_complex1.mp4
# Processing: j_complex2.mov
# Saved → data_processed\jacket\j_complex2.mp4
# Processing: j_shuffle_left.mov
# Saved → data_processed\jacket\j_shuffle_left.mp4
# Processing: j_shuffle_right.mov
# Saved → data_processed\jacket\j_shuffle_right.mp4
# Processing: j_spin.mov
# Saved → data_processed\jacket\j_spin.mp4
# Processing: j_walking_backwards.mov
# Saved → data_processed\jacket\j_walking_backwards.mp4
# Processing: j_walking_towards.mov
# Saved → data_processed\jacket\j_walking_towards.mp4
# Processing: j_walk_left.mov
# Saved → data_processed\jacket\j_walk_left.mp4
# Processing: j_walk_right.mov
# Saved → data_processed\jacket\j_walk_right.mp4
# Processing: s_backwards.mov
# Saved → data_processed\shirt\s_backwards.mp4
# Processing: s_complex.mov
# Saved → data_processed\shirt\s_complex.mp4
# Processing: s_left.mov
# Saved → data_processed\shirt\s_left.mp4
# Processing: s_right.mov
# Saved → data_processed\shirt\s_right.mp4
# Processing: s_shuffle_left.mov
# Saved → data_processed\shirt\s_shuffle_left.mp4
# Processing: s_shuffle_right.mov
# Saved → data_processed\shirt\s_shuffle_right.mp4
# Processing: s_spin.mov
# Saved → data_processed\shirt\s_spin.mp4
# Processing: s_towards.mov
# Saved → data_processed\shirt\s_towards.mp4
# Processing: IMG_3264.MOV
# Saved → data_processed\stage_data\IMG_3264.mp4
# Processing: IMG_3265.MOV
# Saved → data_processed\stage_data\IMG_3265.mp4
# Processing: IMG_3266.MOV
# Saved → data_processed\stage_data\IMG_3266.mp4
# Processing: IMG_3267.MOV
# Saved → data_processed\stage_data\IMG_3267.mp4
# Processing: IMG_3268.MOV
# Saved → data_processed\stage_data\IMG_3268.mp4
# Processing: IMG_3270.MOV
# Saved → data_processed\stage_data\IMG_3270.mp4
# Processing: IMG_3271.MOV
# Saved → data_processed\stage_data\IMG_3271.mp4
# Processing: IMG_3272.MOV
# Saved → data_processed\stage_data\IMG_3272.mp4
# Processing: IMG_3273.MOV
# Saved → data_processed\stage_data\IMG_3273.mp4
# Processing: IMG_3274.MOV
# Saved → data_processed\stage_data\IMG_3274.mp4
# Processing: IMG_3275.MOV
# Saved → data_processed\stage_data\IMG_3275.mp4
# Processing: IMG_3276.MOV
# Saved → data_processed\stage_data\IMG_3276.mp4
# Processing: IMG_3277.MOV
# Saved → data_processed\stage_data\IMG_3277.mp4
# Processing: IMG_3278.MOV
# Saved → data_processed\stage_data\IMG_3278.mp4
# Processing: IMG_3279.MOV
# Saved → data_processed\stage_data\IMG_3279.mp4
# Processing: IMG_3280.MOV
# Saved → data_processed\stage_data\IMG_3280.mp4
# Processing: IMG_3281.MOV
# Saved → data_processed\stage_data\IMG_3281.mp4
# Processing: IMG_3282.MOV
# Saved → data_processed\stage_data\IMG_3282.mp4
# Processing: IMG_3283.MOV
# Saved → data_processed\stage_data\IMG_3283.mp4
# Processing: mary_left_1.mov
# Saved → data_processed\test_videos_2\mary_left_1.mp4
# Processing: mary_left_2.mov
# Saved → data_processed\test_videos_2\mary_left_2.mp4
# Processing: mary_right_1.mov
# Saved → data_processed\test_videos_2\mary_right_1.mp4
# Processing: mary_right_2.mov
# Saved → data_processed\test_videos_2\mary_right_2.mp4
# Processing: soeed3_Right.mov
# Saved → data_processed\test_videos_2\soeed3_Right.mp4
# Processing: speed0_Left.mov
# Saved → data_processed\test_videos_2\speed0_Left.mp4
# Processing: speed0_Right.mov
# Saved → data_processed\test_videos_2\speed0_Right.mp4
# Processing: speed1_Left.mov
# Saved → data_processed\test_videos_2\speed1_Left.mp4
# Processing: speed1_Right.mov
# Saved → data_processed\test_videos_2\speed1_Right.mp4
# Processing: speed2_Left.mov
# Saved → data_processed\test_videos_2\speed2_Left.mp4
# Processing: speed2_Right.mov
# Saved → data_processed\test_videos_2\speed2_Right.mp4
# Processing: speed3_Left.mov
# Saved → data_processed\test_videos_2\speed3_Left.mp4
#
#  All videos processed.
